# %%
import pandas as pd
TS_FILE = "F:/crs/proj/2026_shoreline_analysis/processed/tx_shoreline_obs.parquet"
df = pd.read_parquet(TS_FILE)
print(df)
# Out:
#                date      time                ID  transectStart_X_x  \
# 0        1984-06-23  16:13:17  usa_TX_0001_0001          -93.83873
# 1        1984-09-11  16:14:33  usa_TX_0001_0001          -93.83873
# 2        1984-11-30  16:14:46  usa_TX_0001_0001          -93.83873
# 3        1985-01-01  16:14:42  usa_TX_0001_0001          -93.83873
# 4        1985-03-22  16:15:16  usa_TX_0001_0001          -93.83873
# ...             ...       ...               ...                ...
# 4804388  2022-07-24  16:57:59  usa_TX_0033_0246          -97.14764
# 4804389  2022-08-17  16:58:32  usa_TX_0033_0246          -97.14764
# 4804390  2022-08-28  15:17:57  usa_TX_0033_0246          -97.14764
# 4804391  2022-09-10  16:58:15  usa_TX_0033_0246          -97.14764
# 4804392  2022-10-20  16:58:35  usa_TX_0033_0246          -97.14764
#
#          transectStart_Y_x  transectEnd_X_x  transectEnd_Y_x    distance  \
# 0                29.679420       -93.838165        29.676622  108.794320
# ...

# %%
STATS_FILE = "F:/crs/proj/2026_shoreline_analysis/processed/tx_shoreline_stats.parquet"
df = pd.read_parquet(STATS_FILE)
print(df)
# Out:
#                      ID  transectStart_X  transectStart_Y  transectEnd_X  \
# 0      usa_TX_0001_0001       -93.838730        29.679420     -93.838165
# 1      usa_TX_0001_0002       -93.839165        29.679419     -93.838630
# 2      usa_TX_0001_0003       -93.839580        29.679197     -93.839134
# 3      usa_TX_0001_0004       -93.840030        29.679037     -93.839660
# 4      usa_TX_0001_0005       -93.840515        29.679100     -93.840210
# ...                 ...              ...              ...            ...
# 12121  usa_TX_0033_0242       -97.147250        25.959024     -97.144135
# 12122  usa_TX_0033_0243       -97.147290        25.958645     -97.144150
# 12123  usa_TX_0033_0244       -97.147310        25.958282     -97.144180
# 12124  usa_TX_0033_0245       -97.147415        25.957880     -97.144230
# 12125  usa_TX_0033_0246       -97.147640        25.957376     -97.144264
#
#        transectEnd_Y    lon_mid    lat_mid        x_proj        y_proj  \
# ...

# %%
VAR_STATS = "F:/crs/proj/2026_shoreline_analysis/loess_monthly_basis/variance_budget_by_transect.csv"
df = pd.read_csv( VAR_STATS)
print(df)
# Out:
#                      ID    s_km_rev   rate_ts  trend_direction    var_trend  \
# 0      usa_TX_0001_0001  607.614734 -3.303097             -1.0   873.773638
# 1      usa_TX_0001_0002  607.571082 -4.413831             -1.0  1706.243848
# 2      usa_TX_0001_0003  607.523833 -4.034027             -1.0  1256.200102
# 3      usa_TX_0001_0004  607.475136 -3.373768             -1.0   775.916400
# 4      usa_TX_0001_0005  607.425127 -3.934131             -1.0  1162.262814
# ...                 ...         ...       ...              ...          ...
# 12121  usa_TX_0033_0242    0.199706 -2.677249             -1.0   422.824348
# 12122  usa_TX_0033_0243    0.153794 -2.812745             -1.0   500.154783
# 12123  usa_TX_0033_0244    0.109165 -2.793735             -1.0   485.641798
# 12124  usa_TX_0033_0245    0.061536 -3.044321             -1.0   595.124726
# 12125  usa_TX_0033_0246    0.000000 -3.727576             -1.0   933.713838
#
# ...
